# %%
import pandas as pd
import klib as kl

# %%
pcs_data = pd.read_csv('./validated_csv.csv', index_col=False)
project_type = pd.read_csv('./project_types.csv')
# Out:
# /var/folders/d4/rcb0hfcs0bzgr7z0mw72lc_w0000gn/T/ipykernel_83243/1144237931.py:1: DtypeWarning: Columns (4,13,17,45,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   pcs_data = pd.read_csv('./validated_csv.csv', index_col=False)

# %%
pcs_data = pcs_data.iloc[:, 2:]
pcs_data.head(5)
# Out:
#    division  subdivision item_code  \
# 0       NaN          NaN       NaN
# 1       NaN          NaN       NaN
# 2       NaN          NaN       NaN
# 3       NaN          NaN       NaN
# 4       NaN          NaN       NaN
#
#                                          description  quantity unit  \
# 0                            Estimated Project Total       1.0  NaN
# 1  Standard Manhole, 7-foot or larger Diameter (d...       1.0   EA
# 2  Standard Manhole, 8-foot diameter, (depth up t...   84000.0   EA
# 3                         Escalation and Cost Growth       1.0  NaN
# 4  Standard Manhole, 7-foot diameter, (depth up t...   17969.0   EA
#
#    labor_hourly_rate   man_hrs_per_unit   total_man_hours   labor_total   ...  \
# 0               $-                 $-                $-            $-     ...
# 1               $-                 $-                $-            $-     ...
# 2               $-                 $-                $-            $-     ...
# 3               $-                 $-                $-            $-     ...
# 4               $-                 $-                $-            $-     ...
#
#                                  projectId  \
# 0  0000-0000-0000-0000-0000-0000-0000-0000
# 1  0000-0000-0000-0000-0000-0000-0000-0000
# 2  0000-0000-0000-0000-0000-0000-0000-0000
# 3  0000-0000-0000-0000-0000-0000-0000-0000
# 4  0000-0000-0000-0000-0000-0000-0000-0000
#
#                                    phaseId  \
# 0  0000-0000-0000-0000-0000-0000-0000-0000
# 1  0000-0000-0000-0000-0000-0000-0000-0000
# 2  0000-0000-0000-0000-0000-0000-0000-0000
# 3  0000-0000-0000-0000-0000-0000-0000-0000
# 4  0000-0000-0000-0000-0000-0000-0000-0000
#
#                                  contentId  \
# 0  0000-0000-0000-0000-0000-0000-0000-0000
# 1  0000-0000-0000-0000-0000-0000-0000-0000
# 2  0000-0000-0000-0000-0000-0000-0000-0000
# 3  0000-0000-0000-0000-0000-0000-0000-0000
# 4  0000-0000-0000-0000-0000-0000-0000-0000
#
#                                               fileId  \
# 0  MDAwMC0wMDAwLTAwMDAtMDAwMC0wMDAwLTAwMDAtMDAwMC...
# 1  MDAwMC0wMDAwLTAwMDAtMDAwMC0wMDAwLTAwMDAtMDAwMC...
# 2  MDAwMC0wMDAwLTAwMDAtMDAwMC0wMDAwLTAwMDAtMDAwMC...
# 3  MDAwMC0wMDAwLTAwMDAtMDAwMC0wMDAwLTAwMDAtMDAwMC...
# 4  MDAwMC0wMDAwLTAwMDAtMDAwMC0wMDAwLTAwMDAtMDAwMC...
#
#                            source_file_name unit_7 quantity_6 unit_cost_24  \
# 0  Snapfinger 100 pc Comparison 050724.xlsx    NaN        NaN          NaN
# 1  Snapfinger 100 pc Comparison 050724.xlsx    NaN        NaN          NaN
# 2  Snapfinger 100 pc Comparison 050724.xlsx    NaN        NaN          NaN
# 3  Snapfinger 100 pc Comparison 050724.xlsx    NaN        NaN          NaN
# 4  Snapfinger 100 pc Comparison 050724.xlsx    NaN        NaN          NaN
#
#   total_mat_lab_equip_28 unit_cost_23
# 0                    NaN          NaN
# 1                    NaN          NaN
# 2                    NaN          NaN
# 3                    NaN          NaN
# 4                    NaN          NaN
#
# [5 rows x 47 columns]

# %%
project_type = kl.clean_column_names(project_type)
project_type = project_type.iloc[:, 2:]
project_type.head(5)
# Out:
#    subcategory                                               type  \
# 0           10  Warehouse (10 percent maximum office area, but...
# 1           11                            Large Mercantile Store,
# 2           12                  Factory (excluding tenant fit-up)
# 3           13                                         Warehouses
# 4           14                                               Barn
#
#        project_category construction_category  source  \
# 0  Offices & Warehouses            Commercial       0
# 1                Retail            Commercial       0
# 2                Retail            Commercial       0
# 3  Offices & Warehouses            Commercial       0
# 4  Offices & Warehouses            Commercial       0
#
#                                      id                         created_at  \
# 0  709e86bb-a2bf-4fbe-bffd-dc8540df83cb  2022-01-18T21:37:24.3392757+00:00
# 1  1a3d5500-bcf3-4784-8109-b79d00a1f912  2022-01-18T21:37:24.3738013+00:00
# 2  746ad014-c257-4fb2-be68-41345151ffdc  2022-01-18T21:37:24.4715998+00:00
# 3  ef6fbea4-fbd0-4dd3-a4d9-497e8dbdfe14   2022-01-18T21:37:24.571565+00:00
# 4  dc079f6a-b0cf-41f8-a173-0cc055f87d5a  2022-01-18T21:37:24.6713281+00:00
#
#                           updated_at                       rid  \
# 0  2022-01-18T21:37:24.3392757+00:00  VOd7ALuXooIm7wAAAAAAAA==
# 1  2022-01-18T21:37:24.3738014+00:00  VOd7ALuXooIn7wAAAAAAAA==
# 2  2022-01-18T21:37:24.4715999+00:00  VOd7ALuXooIo7wAAAAAAAA==
# 3   2022-01-18T21:37:24.571565+00:00  VOd7ALuXooIp7wAAAAAAAA==
# 4  2022-01-18T21:37:24.6713281+00:00  VOd7ALuXooIq7wAAAAAAAA==
#
#                                                 self  \
# 0  dbs/VOd7AA==/colls/VOd7ALuXooI=/docs/VOd7ALuXo...
# 1  dbs/VOd7AA==/colls/VOd7ALuXooI=/docs/VOd7ALuXo...
# 2  dbs/VOd7AA==/colls/VOd7ALuXooI=/docs/VOd7ALuXo...
# 3  dbs/VOd7AA==/colls/VOd7ALuXooI=/docs/VOd7ALuXo...
# 4  dbs/VOd7AA==/colls/VOd7ALuXooI=/docs/VOd7ALuXo...
#
#                                      etag   attachments      pk_type  \
# 0  "2a006f8e-0000-0200-0000-676c82be0000"  attachments/  projectType
# 1  "2a00708e-0000-0200-0000-676c82be0000"  attachments/  projectType
# 2  "2a00718e-0000-0200-0000-676c82be0000"  attachments/  projectType
# 3  "2a00728e-0000-0200-0000-676c82be0000"  attachments/  projectType
# 4  "2a00738e-0000-0200-0000-676c82be0000"  attachments/  projectType
#
#    pk_filter          ts account_id updated_by_id
# 0   20240330  1735164606        NaN           NaN
# 1   20240330  1735164606        NaN           NaN
# 2   20240330  1735164606        NaN           NaN
# 3   20240330  1735164606        NaN           NaN
# 4   20240330  1735164606        NaN           NaN

# %%
project_type = project_type[['project_category', 'construction_category', 'id']]

# %%
merged = pd.merge(pcs_data, project_type, how='left', left_on='projectTypeId', right_on='id')

# %%
merged.columns
# Out:
# Index(['division', 'subdivision', 'item_code', 'description', 'quantity',
#        'unit', ' labor_hourly_rate ', ' man_hrs_per_unit ',
#        ' total_man_hours ', ' labor_total ', ' material_qty ',
#        ' material_unit ', ' material ', ' material_total ', ' equipment_qty ',
#        ' equipment_unit ', ' equipment ', ' equipment_total ', ' other_cost1 ',
#        ' other_cost2 ', ' other_cost3 ', ' unit_cost ', ' unit_cost_total ',
#        'subcontractor_qty', 'subcontractor_total', 'subcontractor',
#        ' total_mat_lab_equip ', 'notes', 'project_id', 'project_type_id',
#        'phase_id', 'content_id', 'file_id', 'file_name', 'source_file',
#        'template_type', 'projectTypeId', 'projectId', 'phaseId', 'contentId',
#        'fileId', 'source_file_name', 'unit_7', 'quantity_6', 'unit_cost_24',
#        'total_mat_lab_equip_28', 'unit_cost_23', 'project_category',
#        'construction_category', 'id'],
#       dtype='object')

# %%
merged = merged[['division', 'subdivision', 'item_code', 'description', 'quantity',
       'unit', ' labor_hourly_rate ', ' man_hrs_per_unit ',
       ' total_man_hours ', ' labor_total ', ' material_qty ',
       ' material_unit ', ' material ', ' material_total ', ' equipment_qty ',
       ' equipment_unit ', ' equipment ', ' equipment_total ', ' other_cost1 ',
       ' other_cost2 ', ' other_cost3 ', ' unit_cost ', ' unit_cost_total ',
       'subcontractor_qty', 'subcontractor_total', 'subcontractor',
       ' total_mat_lab_equip ', 'notes', 'project_id', 'project_type_id',
       'phase_id', 'content_id', 'file_id', 'file_name', 'source_file',
       'template_type', 'projectTypeId', 'projectId', 'phaseId', 'contentId',
       'fileId', 'source_file_name', 'project_category',
       'construction_category', 'id']]

# %%
#encode source_file_name into projectId
merged['projectId'] = merged['source_file_name'].astype('category').cat.codes

# %%
merged[' total_mat_lab_equip '] = merged[' total_mat_lab_equip '].str.replace(',', '').str.replace('$', '')

# %%
merged[' total_mat_lab_equip '] = merged[' total_mat_lab_equip '].astype('float64')

# %%
merged[['description', 'quantity',
       'unit', 
       ' total_mat_lab_equip ', 'project_id', 'project_type_id', 'source_file_name',
       'fileId', 'project_category',
       'construction_category', 'id']].to_csv('cleaned.csv', index=False)

# %%
merged = kl.clean_column_names(merged)
# Out:
# ("Duplicate column names detected! Columns with index [36, 37, 38, 39, 40] and names ['project_type_id', 'project_id', 'phase_id', 'content_id', 'file_id'] have been renamed to ['project_type_id_36', 'project_id_37', 'phase_id_38', 'content_id_39', 'file_id_40'].",)

# %%
merged = merged.drop(columns= ['project_type_id_36', 'project_id_37', 'phase_id_38', 'content_id_39', 'file_id_40'])

# %%
len(merged.loc[merged.source_file_name.str.contains('Snapfinger'), 'file_name'].unique())
# Out:
# 242

# %%
len(merged.loc[merged.source_file_name.str.contains('Snapfinger'), 'source_file_name'].unique())
# Out:
# 21

# %%
len(merged.loc[:, 'file_name'].unique())
# Out:
# 409

# %%
merged.columns
# Out:
# Index(['division', 'subdivision', 'item_code', 'description', 'quantity',
#        'unit', 'labor_hourly_rate', 'man_hrs_per_unit', 'total_man_hours',
#        'labor_total', 'material_qty', 'material_unit', 'material',
#        'material_total', 'equipment_qty', 'equipment_unit', 'equipment',
#        'equipment_total', 'other_cost1', 'other_cost2', 'other_cost3',
#        'unit_cost', 'unit_cost_total', 'subcontractor_qty',
#        'subcontractor_total', 'subcontractor', 'total_mat_lab_equip', 'notes',
#        'project_id', 'project_type_id', 'phase_id', 'content_id', 'file_id',
#        'file_name', 'source_file', 'template_type', 'source_file_name',
#        'project_category', 'construction_category', 'id'],
#       dtype='object')

# %%
columns = ['description', 'quantity', 'unit', 'labor_hourly_rate', 'man_hrs_per_unit', 'total_man_hours',
'labor_total', 'material_qty', 'material_unit', 'material', 'material_total', 'equipment_qty', 'equipment_unit', 'equipment',
'equipment_total', 'other_cost1', 'other_cost2', 'other_cost3','unit_cost', 'unit_cost_total', 'subcontractor_qty',
'subcontractor_total', 'subcontractor', 'total_mat_lab_equip', 'source_file_name']

# %%
print(merged.shape)
temp = merged.drop_duplicates(subset=columns)
print(temp.shape)
# Out:
# (29361, 40)
# (18319, 40)

# %%
# find super outliers in temp
temp = temp.loc[temp.total_mat_lab_equip < 1000000000]

# %%
temp.head(5)
# Out:
#     division  subdivision item_code  \
# 7        NaN          NaN       NaN
# 8        NaN          NaN       NaN
# 9        NaN          NaN       NaN
# 10       NaN          NaN       NaN
# 11       NaN          NaN       NaN
#
#                                           description     quantity unit  \
# 7   F.11.32.010 Concourse D Widening - (OPTION 4 -...     1.000000   LS
# 8                          Site Restoration Allowance  2500.000000  NaN
# 9                                                Over   190.476191  NaN
# 10                     Total Estimated Capital Cost =     1.000000  NaN
# 11         Concrete In Place, Platform Paving Bus Bay   625.000000   CY
#
#    labor_hourly_rate man_hrs_per_unit total_man_hours labor_total  ...  \
# 7              $-               $-              $-          $-     ...
# 8              $-               $-              $-          $-     ...
# 9              $-               $-              $-          $-     ...
# 10             $-               $-              $-          $-     ...
# 11             $-               $-              $-          $-     ...
#
#    phase_id content_id file_id  \
# 7       NaN        NaN     NaN
# 8       NaN        NaN     NaN
# 9       NaN        NaN     NaN
# 10      NaN        NaN     NaN
# 11      NaN        NaN     NaN
#
#                                             file_name  \
# 7                F_11_32_010_Concourse_D_Widening.csv
# 8   2024_Nov_-_S_Dekalb_Transit_Hub_Cost_Update_WO...
# 9   MARTA_Clayton_County_Multi-Purpose_O&M_Facilit...
# 10              2025_02_18_I285_BRT__09_Ros_RD_IL.csv
# 11                                     Estimate_1.csv
#
#                               source_file     template_type  \
# 7   F.11.32.010 Concourse D Widening.xlsx             wbs_1
# 8                                     NaN          take_off
# 9                                     NaN    contract_value
# 10                                    NaN  item_description
# 11                                    NaN          take_off
#
#                                      source_file_name      project_category  \
# 7               F.11.32.010 Concourse D Widening.xlsx        Transportation
# 8   2024 Nov - S Dekalb Transit Hub Cost Update WO...         Water & Sewer
# 9   MARTA Clayton County Multi-Purpose O&M Facilit...  Offices & Warehouses
# 10                          2025_02_18_I285 BRT .xlsx         Water & Sewer
# 11                                    Estimate 1.xlsx        Transportation
#
#                   construction_category                                    id
# 7                            Commercial  be9fa3f8-6345-4e5a-a4a1-8ac089f5ea9f
# 8   Civil, Infrastructure & Landscaping  d92accc5-0f88-4784-b6d9-c0cf15d7efaa
# 9                            Commercial  41808243-8069-41f0-bff5-8bb1f4bc05b2
# 10  Civil, Infrastructure & Landscaping  d92accc5-0f88-4784-b6d9-c0cf15d7efaa
# 11                           Commercial  9e5bd34f-933b-4a61-8d48-c5c37c5b5cbd
#
# [5 rows x 40 columns]

# %%
temp[['description', 'quantity',
       'unit', 
       'total_mat_lab_equip', 'project_id', 'project_type_id', 'source_file_name',
        'project_category',
       'construction_category', 'id', 'file_name']].to_csv('cleaned.csv', index=False)

# %%
temp_df = temp.groupby('source_file_name')['total_mat_lab_equip'].sum().reset_index()

# bin
# Out:
#                                       source_file_name  total_mat_lab_equip
# 0    01 Two Rivers Pavilion CD Melvin & Giles & Ass...         2.929319e+07
# 1                                 101 NLIF CHURCH.xlsx         5.134198e+06
# 2       20230927_final_alternative_OPCC_forPCS(1).xlsx         1.226821e+08
# 3    2024 Nov - S Dekalb Transit Hub Cost Update 20...         7.843516e+08
# 4    2024 Nov - S Dekalb Transit Hub Cost Update WO...         4.112312e+08
# ..                                                 ...                  ...
# 128       Technical Support Campus Upgrade 30% CD.xlsx         4.177347e+07
# 129                       Updated Unit Cost Sheet.xlsx         6.668593e+05
# 130  WSP - MARTA - Comment Responses for South DeKa...         8.672481e+07
# 131                        Walnut Creek Expansion.xlsx         4.666158e+08
# 132  Wynnton Road Retaining Wall Replacement Nov 20...         2.195931e+06
#
# [133 rows x 2 columns]

# %%
len(merged.loc[merged.source_file_name.str.contains('Snapfinger'), 'file_name'].unique())
# Out:
# 242
